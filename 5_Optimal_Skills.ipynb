# %% [markdown]
# # What is the most optimal skill to learn for Data Analysts?
#
# #### Methodology
#
# 1. Continue from last notebook to find percent of postings with skill
# 2. Visualize median salary vs percent skill demand
# 3. (Optional) Determine if certain technologies are more prevalent

# %% [markdown]
# ## Import Libraries and Data

# %% [markdown]
# Import the libraries, data and change the `job_posted_date` to a datetime type.

# %%
# Importing Libraries
import ast
import pandas as pd
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# ## Clean Data
#
# Filters the original dataset to only get rows where the job title is 'Data Analyst' and the country is 'Spain', to create a new DataFrame `df_DA_Spain`. Drop NaN values from the 'salary_year_avg' column. Then it uses the `explode` method on the `job_skills` column to create a new row in a new DataFrame (`df_DA_Spain_exploded`) for each skill associated with a job. Finally, it displays the first 5 entries of the `salary_year_avg` and `job_skills` columns.

# %%
df_DA_Spain = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'Spain')].copy()

# Drop NaN values from the 'salary_year_avg' column for accurate visualization
df_DA_Spain = df_DA_Spain.dropna(subset=['salary_year_avg'])

df_DA_Spain_exploded = df_DA_Spain.explode('job_skills')

df_DA_Spain_exploded[['salary_year_avg', 'job_skills']].head(5)
# Out:
#        salary_year_avg  job_skills
# 17710          51014.0        None
# 32177         111175.0         sql
# 32177         111175.0      python
# 32177         111175.0           r
# 32177         111175.0  databricks

# %% [markdown]
# ## Calculate Percent of Job Postings that Have Skills

# %% [markdown]
# Group the data by job skills and calculates the count and median salary for each skill, sorting the results in descending order by count. It then renames the columns. Calculates the percentage that each skill count represents out of the total number of Data Analyst jobs. Finally, filter out any skills that don't have any jobs associated with them.

# %%
# using df_DA find the count of skills and also the median salary for each skill
df_DA_skills = df_DA_Spain_exploded.groupby('job_skills')['salary_year_avg'].agg(['count', 'median']).sort_values(by='count', ascending=False)

df_DA_skills = df_DA_skills.rename(columns={'count': 'skill_count', 'median': 'median_salary'})

DA_job_count = len(df_DA_Spain)  # Find count of Data Analyst jobs in Spain with salary info

df_DA_skills['skill_percent'] = df_DA_skills['skill_count'] / DA_job_count * 100

df_DA_skills = df_DA_skills[df_DA_skills['skill_count'] > 0]

df_DA_skills
# Out:
#               skill_count  median_salary  skill_percent
# job_skills
# sql                    17        89100.0      56.666667
# python                 14        98500.0      46.666667
# tableau                 9        98500.0      30.000000
# excel                   5        72900.0      16.666667
# power bi                4        73352.0      13.333333
# pandas                  4       108087.5      13.333333
# looker                  4       111175.0      13.333333
# airflow                 3        98500.0      10.000000
# jupyter                 3       105000.0      10.000000
# snowflake               3        89100.0      10.000000
# r                       3        98500.0      10.000000
# word                    3        72900.0      10.000000
# databricks              2       104837.5       6.666667
# numpy                   2       111175.0       6.666667
# qlik                    2       100203.0       6.666667
# go                      2       100137.5       6.666667
# flow                    2        95770.0       6.666667
# spreadsheet             2       101750.0       6.666667
# redshift                1        57500.0       3.333333
# sap                     1       118640.0       3.333333
# scikit-learn            1       111175.0       3.333333
# java                    1        80850.0       3.333333
# react                   1       111202.0       3.333333
# bigquery                1        89100.0       3.333333
# spark                   1        80850.0       3.333333
# azure                   1        94750.0       3.333333
# aws                     1        80850.0       3.333333
# vba                     1        57500.0       3.333333
# visio                   1        72900.0       3.333333
# smartsheet              1       155000.0       3.333333
# docker                  1        80850.0       3.333333
# powerpoint              1        72900.0       3.333333
# git                     1        89100.0       3.333333
# outlook                 1        57500.0       3.333333
# angular                 1       111202.0       3.333333
# node.js                 1       111202.0       3.333333
# node                    1        57500.0       3.333333
# mysql                   1       100500.0       3.333333
# matplotlib              1       111175.0       3.333333
# matlab                  1        80850.0       3.333333
# gitlab                  1        89100.0       3.333333
# kafka                   1        80850.0       3.333333
# npm                     1       111202.0       3.333333

# %% [markdown]
# ## Median Salary vs Percent Skill Demand

# %% [markdown]
# Filters for Data Analyst skills that exceed a certain percentage (`skill_limit`).

# %%
skill_limit = 5

df_DA_skills_high_demand = df_DA_skills[df_DA_skills['skill_percent'] > skill_limit]

# %% [markdown]
# Create a scatter plot to visualize the relationship between the percentage of Data Analyst jobs that require specific skills and the median salary for those skills.

# %%
# !pip install adjustText
# Out:
# Collecting adjustText
#   Downloading adjustText-1.2.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/stable_python/lib/python3.11/site-packages (from adjustText) (1.26.4)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/stable_python/lib/python3.11/site-packages (from adjustText) (3.9.2)
# Collecting scipy (from adjustText)
#   Downloading scipy-1.14.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/stable_python/lib/python3.11/site-packages (from matplotlib->adjustText) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/stable_python/lib/python3.11/site-packages (from matplotlib->adjustText) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/stable_python/lib/python3.11/site-packages (from matplotlib->adjustText) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/stable_python/lib/python3.11/site-packages (from matplotlib->adjustText) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/stable_python/lib/python3.11/site-packages (from matplotlib->adjustText) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/stable_python/lib/python3.11/site-packages (from matplotlib->adjustText) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/stable_python/lib/python3.11/site-packages (from matplotlib->adjustText) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/stable_python/lib/python3.11/site-packages (from matplotlib->adjustText) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/stable_python/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->adjustText) (1.16.0)
# Downloading adjustText-1.2.0-py3-none-any.whl (12 kB)
# Downloading scipy-1.14.1-cp311-cp311-macosx_14_0_arm64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 9.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: scipy, adjustText
# Successfully installed adjustText-1.2.0 scipy-1.14.1

# %%
from adjustText import adjust_text

plt.scatter(df_DA_skills_high_demand['skill_percent'], df_DA_skills_high_demand['median_salary'])
plt.xlabel('Percent of Data Analyst Jobs')
plt.ylabel('Median Salary ($USD)')  # Assuming this is the label you want for y-axis
plt.title('Most Optimal Skills for Data Analysts in Spain')

# Get current axes, set limits, and format axes
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))  # Example formatting y-axis

# Add labels to points and collect them in a list
texts = []
for i, txt in enumerate(df_DA_skills_high_demand.index):
    texts.append(plt.text(df_DA_skills_high_demand['skill_percent'].iloc[i], df_DA_skills_high_demand['median_salary'].iloc[i], " " + txt))

# Adjust text to avoid overlap and add arrows
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

plt.show()

# %% [markdown]
# ## Bonus: Coloring by Technology

# %% [markdown]
# We're going to add color labels based on technology.
#
# Removes duplicate entries and any rows with missing values. Then, it combines all dictionary entries into a single dictionary, summing values for keys that repeat across entries. To ensure each key's values are unique, it converts the values to a set and then back to a list. The final result is a dictionary where each key represents a skill and each value is a list of unique attributes associated with that skill.

# %%
df_technology = df['job_type_skills'].copy()

# remove duplicates
df_technology = df_technology.drop_duplicates()

# remove NaN values
df_technology = df_technology.dropna()

# combine all dictionaries into one
technology_dict = {}
for row in df_technology:
    row_dict = ast.literal_eval(row)  # convert string to dictionary
    for key, value in row_dict.items():
        if key in technology_dict:  # if key already exists in technology_dict, add value to existing value
            technology_dict[key] += value
        else:                       # if key does not exist in technology_dict, add key and value
            technology_dict[key] = value

# remove duplicates by converting values to set then back to list
for key, value in technology_dict.items():
    technology_dict[key] = list(set(value))

technology_dict
# Out:
# {'analyst_tools': ['esquisse',
#   'sheets',
#   'excel',
#   'qlik',
#   'cognos',
#   'dax',
#   'splunk',
#   'microstrategy',
#   'word',
#   'ms access',
#   'visio',
#   'nuix',
#   'sap',
#   'datarobot',
#   'alteryx',
#   'tableau',
#   'msaccess',
#   'looker',
#   'sas',
#   'powerpoint',
#   'ssrs',
#   'outlook',
#   'spss',
#   'power bi',
#   'spreadsheet',
#   'sharepoint',
#   'ssis',
#   'powerbi'],
#  'programming': ['kotlin',
#   'dart',
#   'c',
#   'cobol',
#   'python',
#   'css',
#   'pascal',
#   'fortran',
#   'javascript',
#   'objective-c',
#   'powershell',
#   'scala',
#   'elixir',
#   'erlang',
#   'bash',
#   'java',
#   'vb.net',
#   'mongodb',
#   'crystal',
#   'rust',
#   'c#',
#   'haskell',
#   'mongo',
#   'assembly',
#   'groovy',
#   'clojure',
#   'ocaml',
#   'visual basic',
#   't-sql',
#   'perl',
#   'sas',
#   'lisp',
#   'visualbasic',
#   'r',
#   'go',
#   'apl',
#   'html',
#   'nosql',
#   'solidity',
#   'lua',
#   'vba',
#   'f#',
#   'php',
#   'no-sql',
#   'matlab',
#   'julia',
#   'delphi',
#   'sql',
#   'sass',
#   'c++',
#   'shell',
#   'golang',
#   'swift',
#   'typescript',
#   'ruby'],
#  'cloud': ['digitalocean',
#   'aws',
#   'oracle',
#   'vmware',
#   'bigquery',
#   'snowflake',
#   'firebase',
#   'linode',
#   'gcp',
#   'heroku',
#   'colocation',
#   'openstack',
#   'aurora',
#   'watson',
#   'redshift',
#   'databricks',
#   'ovh',
#   'ibm cloud',
#   'azure'],
#  'libraries': ['seaborn',
#   'tidyverse',
#   'rshiny',
#   'plotly',
#   'spark',
#   'nltk',
#   'pytorch',
#   'scikit-learn',
#   'pyspark',
#   'flutter',
#   'theano',
#   'qt',
#   'opencv',
#   'tensorflow',
#   'pandas',
#   'shogun',
#   'mxnet',
#   'airflow',
#   'keras',
#   'ionic',
#   'numpy',
#   'gdpr',
#   'react',
#   'xamarin',
#   'kafka',
#   'matplotlib',
#   'hadoop',
#   'mlpack',
#   'capacitor',
#   'dplyr',
#   'huggingface',
#   'tidyr',
#   'dlib',
#   'chainer',
#   'gtx',
#   'mlr',
#   'electron',
#   'ggplot2',
#   'graphql',
#   'spring',
#   'selenium',
#   'cordova',
#   'jupyter',
#   'hugging face'],
#  'other': ['kubernetes',
#   'flow',
#   'git',
#   'terminal',
#   'docker',
#   'svn',
#   'bitbucket',
#   'atlassian',
#   'homebrew',
#   'npm',
#   'yarn',
#   'unity',
#   'gitlab',
#   'chef',
#   'puppet',
#   'ansible',
#   'terraform',
#   'github',
#   'unreal',
#   'jenkins',
#   'codecommit',
#   'pulumi'],
#  'databases': ['db2',
#   'cassandra',
#   'couchdb',
#   'couchbase',
#   'dynamodb',
#   'mongodb',
#   'redis',
#   'elasticsearch',
#   'mariadb',
#   'postgresql',
#   'firestore',
#   'sqlserver',
#   'firebase',
#   'sqlite',
#   'sql server',
#   'neo4j',
#   'mysql'],
#  'os': ['arch',
#   'macos',
#   'wsl',
#   'ubuntu',
#   'centos',
#   'kali',
#   'windows',
#   'linux',
#   'unix',
#   'redhat',
#   'debian',
#   'suse',
#   'fedora'],
#  'async': ['wrike',
#   'workfront',
#   'notion',
#   'planner',
#   'clickup',
#   'jira',
#   'microsoft lists',
#   'monday.com',
#   'wimi',
#   'trello',
#   'confluence',
#   'airtable',
#   'asana',
#   'dingtalk',
#   'smartsheet'],
#  'webframeworks': ['jquery',
#   'rubyon rails',
#   'gatsby',
#   'drupal',
#   'fastapi',
#   'angular.js',
#   'node',
#   'ember.js',
#   'react.js',
#   'asp.net',
#   'asp.netcore',
#   'next.js',
#   'flask',
#   'laravel',
#   'node.js',
#   'vue.js',
#   'nuxt.js',
#   'play framework',
#   'vue',
#   'ruby on rails',
#   'phoenix',
#   'asp.net core',
#   'symfony',
#   'deno',
#   'svelte',
#   'blazor',
#   'express',
#   'django',
#   'fastify',
#   'angular',
#   'ruby'],
#  'sync': ['twilio',
#   'ringcentral',
#   'google chat',
#   'slack',
#   'rocketchat',
#   'mattermost',
#   'wire',
#   'webex',
#   'symphony',
#   'microsoft teams',
#   'zoom',
#   'unify']}

# %% [markdown]
# This code converts a dictionary into a pandas DataFrame, then explodes the 'skills' column, creating multiple rows for each 'technology' entry if it contains multiple skills.

# %%
# turn dictionary into dataframe
df_technology = pd.DataFrame(list(technology_dict.items()), columns=['technology', 'skills'])

df_technology = df_technology.explode('skills')

df_technology
# Out:
#        technology           skills
# 0   analyst_tools         esquisse
# 0   analyst_tools           sheets
# 0   analyst_tools            excel
# 0   analyst_tools             qlik
# 0   analyst_tools           cognos
# ..            ...              ...
# 9            sync            webex
# 9            sync         symphony
# 9            sync  microsoft teams
# 9            sync             zoom
# 9            sync            unify
#
# [256 rows x 2 columns]

# %% [markdown]
# Merges two DataFrames, `df_DA_skills` and `df_technology`, based on the columns 'job_skills' and 'skills' respectively, creating a new DataFrame `df_DA_skills_tech`.

# %%
# merge df_DA_skills and df_technology
df_DA_skills_tech = df_DA_skills.merge(df_technology, left_on='job_skills', right_on='skills')

df_DA_skills_tech
# Out:
#     skill_count  median_salary  skill_percent     technology        skills
# 0            17        89100.0      56.666667    programming           sql
# 1            14        98500.0      46.666667    programming        python
# 2             9        98500.0      30.000000  analyst_tools       tableau
# 3             5        72900.0      16.666667  analyst_tools         excel
# 4             4        73352.0      13.333333  analyst_tools      power bi
# 5             4       108087.5      13.333333      libraries        pandas
# 6             4       111175.0      13.333333  analyst_tools        looker
# 7             3        98500.0      10.000000      libraries       airflow
# 8             3       105000.0      10.000000      libraries       jupyter
# 9             3        89100.0      10.000000          cloud     snowflake
# 10            3        98500.0      10.000000    programming             r
# 11            3        72900.0      10.000000  analyst_tools          word
# 12            2       104837.5       6.666667          cloud    databricks
# 13            2       111175.0       6.666667      libraries         numpy
# 14            2       100203.0       6.666667  analyst_tools          qlik
# 15            2       100137.5       6.666667    programming            go
# 16            2        95770.0       6.666667          other          flow
# 17            2       101750.0       6.666667  analyst_tools   spreadsheet
# 18            1        57500.0       3.333333          cloud      redshift
# 19            1       118640.0       3.333333  analyst_tools           sap
# 20            1       111175.0       3.333333      libraries  scikit-learn
# 21            1        80850.0       3.333333    programming          java
# 22            1       111202.0       3.333333      libraries         react
# 23            1        89100.0       3.333333          cloud      bigquery
# 24            1        80850.0       3.333333      libraries         spark
# 25            1        94750.0       3.333333          cloud         azure
# 26            1        80850.0       3.333333          cloud           aws
# 27            1        57500.0       3.333333    programming           vba
# 28            1        72900.0       3.333333  analyst_tools         visio
# 29            1       155000.0       3.333333          async    smartsheet
# 30            1        80850.0       3.333333          other        docker
# 31            1        72900.0       3.333333  analyst_tools    powerpoint
# 32            1        89100.0       3.333333          other           git
# 33            1        57500.0       3.333333  analyst_tools       outlook
# 34            1       111202.0       3.333333  webframeworks       angular
# 35            1       111202.0       3.333333  webframeworks       node.js
# 36            1        57500.0       3.333333  webframeworks          node
# 37            1       100500.0       3.333333      databases         mysql
# 38            1       111175.0       3.333333      libraries    matplotlib
# 39            1        80850.0       3.333333    programming        matlab
# 40            1        89100.0       3.333333          other        gitlab
# 41            1        80850.0       3.333333      libraries         kafka
# 42            1       111202.0       3.333333          other           npm

# %% [markdown]
# Filters `df_DA_skills_tech` to select rows where the 'percent' column exceeds a specified threshold, storing the result in `df_DA_skills_tech_high_demand`.

# %%
df_DA_skills_tech_high_demand = df_DA_skills_tech[df_DA_skills_tech['skill_percent'] > skill_limit]

# %% [markdown]
# Plot the results in a scatter plot, coloring the points based on the 'technology' column.

# %%
sns.scatterplot(
    data=df_DA_skills_tech_high_demand,
    x='skill_percent',
    y='median_salary',
    hue='technology'
)

sns.despine()
sns.set_theme(style='ticks')

# Prepare texts for adjustText
texts = []
for i, txt in enumerate(df_DA_skills_high_demand.index):
    texts.append(plt.text(df_DA_skills_high_demand['skill_percent'].iloc[i], df_DA_skills_high_demand['median_salary'].iloc[i], txt))

# Adjust text to avoid overlap
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

# Set axis labels, title, and legend
plt.xlabel('Percent of Data Analyst Jobs')
plt.ylabel('Median Yearly Salary')
plt.title('Most Optimal Skills for Data Analysts in Spain')
plt.legend(title='Technology')

from matplotlib.ticker import PercentFormatter
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))
ax.xaxis.set_major_formatter(PercentFormatter(decimals=0))

# Adjust layout and display plot 
plt.tight_layout()
plt.show()
